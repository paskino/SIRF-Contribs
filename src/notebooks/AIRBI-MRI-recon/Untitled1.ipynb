# %%
from cil.io.utilities import HDF5_utilities

# %%
HDF5_utilities.print_metadata('work/data/h5/1meas_MID00614_FID129152_CONVENTIONAL_RECON_SEQD_GF2_AX_RL_mod.h5', group='/', depth=-1)
# Out:
# 	 - dataset : <HDF5 group "/dataset" (2 members)>
# 		 - data : <HDF5 dataset "data": shape (9450,), type "|V372">
# 		 - xml : <HDF5 dataset "xml": shape (1,), type "|O">

# %%
HDF5_utilities.get_dataset_metadata('work/data/h5/1meas_MID00614_FID129152_CONVENTIONAL_RECON_SEQD_GF2_AX_RL_mod.h5', "dataset/data")
# Out:
# {'ndim': 1,
#  'shape': (9450,),
#  'size': 9450,
# ...
